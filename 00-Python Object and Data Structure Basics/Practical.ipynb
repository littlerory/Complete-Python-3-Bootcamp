# %%
from ctypes.wintypes import LPWIN32_FIND_DATAA

my_name = "Rory"
print("Hello " + my_name)
# Out:
# Hello Rory

# %%
print('This is a sting {}'.format('INSERTED'))
# Out:
# This is a sting INSERTED

# %%
print('The {2} {1} {0}'.format('fox','brown','quick'))
# Out:
# The quick brown fox

# %%
print('The {q} {b} {f}'.format(f='fox',b='brown',q='quick'))
# Out:
# The quick brown fox

# %%
result = 104.12345

# %%
result
# Out:
# 104.12345

# %%
print("The result was {r:1.3f}".format(r=result))
# Out:
# The result was 104.123

# %%
name = "Rory"

# %%
print(f'Hello my name is {name}')
# Out:
# Hello my name is Rory

# %%
# %%writefile myfile.txt
# Hello this is a text file
# This is the second line
# the third line
# Out:
# Overwriting myfile.txt

# %%
myfile = open('myfile.txt')

# %%
myfile = open('nofile.txt')
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[6], line 1
# ----> 1 myfile = open('nofile.txt')
#
# File /Library/Frameworks/Python.framework/Versions/3.14/lib/python3.14/site-packages/IPython/core/interactiveshell.py:344, in _modified_open(file, *args, **kwargs)
#     337 if file in {0, 1, 2}:
#     338     raise ValueError(
#     339         f"IPython won't let you open fd={file} by default "
#     340         "as it is likely to crash IPython. If you know what you are doing, "
#     341         "you can use builtins' open."
#     342     )
# --> 344 return io_open(file, *args, **kwargs)
#
# FileNotFoundError: [Errno 2] No such file or directory: 'nofile.txt'

# %%
pwd
# Out:
# '/Users/F5673747/PycharmProjects/Complete-Python-3-Bootcamp/00-Python Object and Data Structure Basics'

# %%
myfile = open('myfile.txt')

# %%
myfile.read()
# Out:
# 'Hello this is a text file\nThis is the second line\nthe third line\n'

# %%
myfile.seek(0)
# Out:
# 0

# %%
myfile.read()
# Out:
# 'Hello this is a text file\nThis is the second line\nthe third line\n'

# %%
myfile.seek(0)
# Out:
# 0

# %%
myfile.readlines()
# Out:
# ['Hello this is a text file\n',
#  'This is the second line\n',
#  'the third line\n']

# %%
pdd
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[14], line 1
# ----> 1 pdd
#
# NameError: name 'pdd' is not defined

# %%
pwd
# Out:
# '/Users/F5673747/PycharmProjects/Complete-Python-3-Bootcamp/00-Python Object and Data Structure Basics'

# %%
myfile.close()

# %%
with open('myfile.txt') as my_new_file:
    contents = my_new_file.read()

# %%
with open('myfile.txt',mode='r') as my_file:
    contents = my_file.read()

# %%
contents
# Out:
# 'Hello this is a text file\nThis is the second line\nthe third line\n'
